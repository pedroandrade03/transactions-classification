# %% [markdown]
# # Etapa 1 - Leitura da base e Análise de Dados

# %% [markdown]
# ## Inicializacao do ambiente Spark

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("PySpark Transactions Classification")
    .master("local[*]")
    .config("spark.driver.memory", "4g")
    .config("spark.executor.memory", "4g")
    .getOrCreate()
)

# %% [markdown]
# ## Leitura da base de dados

# %%
# A leitura via CSV foi usada apenas na etapa inicial de conversao;
# depois disso, mantemos a leitura em Parquet por melhor performance no Spark.

# dataframe = (
#     spark.read
#     .csv("./synthetic_fraud_data.csv", header=True, inferSchema=True)
# )
#
# dataframe.write.parquet("synthetic_fraud_data.parquet")

dataframe = (
    spark.read
    .parquet("./synthetic_fraud_data.parquet")
)

dataframe.createOrReplaceTempView("transactions_raw")

rows_count = dataframe.count()
print(f"Número de linhas no DataFrame: {rows_count}")
# Out:
# Número de linhas no DataFrame: 7483766

# %% [markdown]
# ## Estrutura e visualização inicial da base

# %%
dataframe.printSchema()
# Out:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- card_number: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- merchant_category: string (nullable = true)
#  |-- merchant_type: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- city_size: string (nullable = true)
#  |-- card_type: string (nullable = true)
#  |-- card_present: boolean (nullable = true)
#  |-- device: string (nullable = true)
#  |-- channel: string (nullable = true)
#  |-- device_fingerprint: string (nullable = true)
#  |-- ip_address: string (nullable = true)
#  |-- distance_from_home: integer (nullable = true)
#  |-- high_risk_merchant: boolean (nullable = true)
#  |-- transaction_hour: integer (nullable = true)
#  |-- weekend_transaction: boolean (nullable = true)
#  |-- velocity_last_hour: string (nullable = true)
#  |-- is_fraud: boolean (nullable = true)

# %%
dataframe.show()
# Out:
# +--------------+-----------+----------------+--------------------+-----------------+-------------+--------------------+---------+--------+---------+------------+---------+---------------+------------+-----------+-------+--------------------+---------------+------------------+------------------+----------------+-------------------+--------------------+--------+
# |transaction_id|customer_id|     card_number|           timestamp|merchant_category|merchant_type|            merchant|   amount|currency|  country|        city|city_size|      card_type|card_present|     device|channel|  device_fingerprint|     ip_address|distance_from_home|high_risk_merchant|transaction_hour|weekend_transaction|  velocity_last_hour|is_fraud|
# +--------------+-----------+----------------+--------------------+-----------------+-------------+--------------------+---------+--------+---------+------------+---------+---------------+------------+-----------+-------+--------------------+---------------+------------------+------------------+----------------+-------------------+--------------------+--------+
# |   TX_2504de95| CUST_66055| 374034413507317|2024-10-21 22:58:...|        Education|     supplies|University Bookstore|   513.59|     USD|      USA| Los Angeles|    large|    Gold Credit|       false|       Edge|    web|46a427a1cfa747b75...|  143.38.46.200|                 0|             false|              22|              false|{'num_transaction...|   false|
# |   TX_a486b692| CUST_42953|6369936060334817|2024-10-21 22:58:...|    Entertainment|       events|             StubHub|683010.87|     NGN|  Nigeria|Unknown City|   medium|   Basic Credit|       false|Android App| mobile|f88bc258b0ee810ac...|123.189.220.204|                 1|              true|              22|              false|{'num_transaction...|    true|
# |   TX_f2151c65| CUST_60881|4077491003448934|2024-10-21 22:58:...|              Gas|        major|               Exxon|    16.76|     BRL|   Brazil|Unknown City|   medium|Platinum Credit|        true|Chip Reader|    pos|ed8f0dceaa4bf190a...|157.186.157.167|                 1|             false|              22|              false|{'num_transaction...|    true|
# |   TX_fac513b9| CUST_37797|6015043998953426|2024-10-21 22:58:...|        Education|     supplies|      Barnes & Noble|130608.99|     RUB|   Russia|Unknown City|   medium|   Basic Credit|       false|       Edge|    web|3cad272bd35ff4a36...|   130.16.18.86|                 1|             false|              22|              false|{'num_transaction...|    true|
# |   TX_c02341fd| CUST_88703|4248393904399709|2024-10-21 22:58:...|          Grocery|       online|        Amazon Fresh|   112.31|     EUR|   France|Unknown City|   medium|   Basic Credit|       false|     Safari|    web|85d0d8de0110f9fac...| 58.169.147.121|                 0|             false|              22|              false|{'num_transaction...|   false|
# |   TX_082bcd03| CUST_48653|6120921182986801|2024-10-21 22:58:...|       Healthcare|      medical|      Medical Center|   167.09|     GBP|       UK|Unknown City|   medium|   Basic Credit|       false|     Safari|    web|b1d14ffa72f6c6c88...|253.246.193.130|                 0|             false|              22|              false|{'num_transaction...|   false|
# |   TX_d970180f| CUST_64529| 370350792330756|2024-10-21 22:58:...|          Grocery|       online|           Instacart| 33008.98|     RUB|   Russia|Unknown City|   medium|Platinum Credit|       false|    iOS App| mobile|0056703a3beec708c...|  70.239.20.170|                 0|             false|              22|              false|{'num_transaction...|   false|
# |   TX_2af437b8| CUST_11839| 379717757751914|2024-10-21 22:58:...|    Entertainment|    streaming|             HBO Max| 31905.93|     JPY|    Japan|Unknown City|   medium|Platinum Credit|       false|    Firefox|    web|433643538732bdc7f...|  170.160.9.113|                 0|              true|              22|              false|{'num_transaction...|   false|
# |   TX_38964cd9| CUST_16129|4186642904415251|2024-10-21 22:58:...|              Gas|        major|               Mobil|  1589.96|     SGD|Singapore|Unknown City|   medium|Platinum Credit|       false|     Safari|    web|e7177e6102ff822d1...| 209.102.136.56|                 0|             false|              22|              false|{'num_transaction...|   false|
# |   TX_c4d17bc5| CUST_15520|6797471677517945|2024-10-21 22:58:...|    Entertainment|       gaming|      Nintendo eShop| 12308.08|     RUB|   Russia|Unknown City|   medium|    Basic Debit|       false|    iOS App| mobile|2d2c715cb8a95f6a2...|   95.153.69.23|                 0|              true|              22|              false|{'num_transaction...|   false|
# |   TX_76e0ce7c| CUST_73598|4342596238283549|2024-10-21 22:58:...|       Healthcare|      medical|      Local Hospital|   390.97|     SGD|Singapore|Unknown City|   medium|    Basic Debit|       false|     Chrome|    web|14eafe44acf88e3e9...| 243.136.12.206|                 0|             false|              22|              false|{'num_transaction...|   false|
# |   TX_d6c06b2b| CUST_69635|6233576571847925|2024-10-21 22:58:...|       Restaurant|    fast_food|          McDonald's|    641.8|     AUD|Australia|Unknown City|   medium|    Gold Credit|       false|     Chrome|    web|a8a324bfa3df52a60...|    75.11.58.36|                 0|             false|              22|              false|{'num_transaction...|   false|
# |   TX_8fe5239a| CUST_56674| 371478693602152|2024-10-21 22:58:...|           Travel|    transport|               Hertz|    233.3|     USD|      USA|Philadelphia|   medium|Platinum Credit|       false|     Safari|    web|ae06b0161e8dde26a...| 107.224.108.59|                 0|              true|              22|              false|{'num_transaction...|   false|
# |   TX_602f2a9b| CUST_83212|4202232655101134|2024-10-21 22:58:...|       Restaurant|      premium|            Morton's| 407532.4|     NGN|  Nigeria|Unknown City|   medium|Platinum Credit|       false|    Firefox|    web|d3f504638284169f6...|  67.216.56.105|                 1|             false|              22|              false|{'num_transaction...|    true|
# |   TX_28569479| CUST_76786|6011032112473696|2024-10-21 22:58:...|           Travel|      booking|              Airbnb| 28316.84|     MXN|   Mexico|Unknown City|   medium|  Premium Debit|       false|     Chrome|    web|d385dcc9c8336f938...| 94.207.181.224|                 0|              true|              22|              false|{'num_transaction...|   false|
# |   TX_dd97f930| CUST_88348|6996502795801883|2024-10-21 22:58:...|           Retail|       online|                Etsy|    384.3|     GBP|       UK|Unknown City|   medium|    Basic Debit|       false|Android App| mobile|32f948f4f642e9744...| 122.41.116.226|                 0|             false|              22|              false|{'num_transaction...|   false|
# |   TX_092f9443| CUST_93864|4789286113200608|2024-10-21 22:58:...|           Travel|       hotels|              Hilton|  1042.07|     CAD|   Canada|Unknown City|   medium|  Premium Debit|       false|     Safari|    web|70209b09316c5ee0f...| 244.94.171.203|                 0|              true|              22|              false|{'num_transaction...|   false|
# |   TX_74f95664| CUST_98391|6757085408307703|2024-10-21 22:58:...|           Retail|     physical|            Best Buy|   654.72|     SGD|Singapore|Unknown City|   medium|    Basic Debit|       false|    iOS App| mobile|54b49ad10c5d9d8d1...| 113.71.147.167|                 1|             false|              22|              false|{'num_transaction...|   false|
# |   TX_9f245d68| CUST_24359| 374426065046323|2024-10-21 22:58:...|       Healthcare|     pharmacy|            Rite Aid|  1213.59|     CAD|   Canada|Unknown City|   medium|Platinum Credit|       false|    Firefox|    web|d81d760310ca07ffd...|  106.54.222.32|                 0|             false|              22|              false|{'num_transaction...|   false|
# |   TX_8fd48222| CUST_70988|6864364124650484|2024-10-21 22:58:...|       Healthcare|     pharmacy|          DuaneReade|110345.31|     NGN|  Nigeria|Unknown City|   medium|    Basic Debit|       false|    iOS App| mobile|1a7fc37a778499efb...| 225.35.104.157|                 0|             false|              22|              false|{'num_transaction...|   false|
# +--------------+-----------+----------------+--------------------+-----------------+-------------+--------------------+---------+--------+---------+------------+---------+---------------+------------+-----------+-------+--------------------+---------------+------------------+------------------+----------------+-------------------+--------------------+--------+
# only showing top 20 rows

# %% [markdown]
# ## Analise inicial da coluna alvo, nulos e duplicatas

# %%
spark.sql("SELECT is_fraud ,COUNT(is_fraud) FROM transactions_raw GROUP BY is_fraud ORDER BY is_fraud").show()
# Out:
# +--------+---------------+
# |is_fraud|count(is_fraud)|
# +--------+---------------+
# |   false|        5989047|
# |    true|        1494719|
# +--------+---------------+

# %%
spark.sql("""
    SELECT
        SUM(CASE WHEN transaction_id IS NULL THEN 1 ELSE 0 END) AS transaction_id_nulls,
        SUM(CASE WHEN customer_id IS NULL THEN 1 ELSE 0 END) AS customer_id_nulls,
        SUM(CASE WHEN card_number IS NULL THEN 1 ELSE 0 END) AS card_number_nulls,
        SUM(CASE WHEN timestamp IS NULL THEN 1 ELSE 0 END) AS timestamp_nulls,
        SUM(CASE WHEN merchant_category IS NULL THEN 1 ELSE 0 END) AS merchant_category_nulls,
        SUM(CASE WHEN merchant_type IS NULL THEN 1 ELSE 0 END) AS merchant_type_nulls,
        SUM(CASE WHEN merchant IS NULL THEN 1 ELSE 0 END) AS merchant_nulls,
        SUM(CASE WHEN amount IS NULL THEN 1 ELSE 0 END) AS amount_nulls,
        SUM(CASE WHEN currency IS NULL THEN 1 ELSE 0 END) AS currency_nulls,
        SUM(CASE WHEN country IS NULL THEN 1 ELSE 0 END) AS country_nulls,
        SUM(CASE WHEN city IS NULL THEN 1 ELSE 0 END) AS city_nulls,
        SUM(CASE WHEN city_size IS NULL THEN 1 ELSE 0 END) AS city_size_nulls,
        SUM(CASE WHEN card_type IS NULL THEN 1 ELSE 0 END) AS card_type_nulls,
        SUM(CASE WHEN card_present IS NULL THEN 1 ELSE 0 END) AS card_present_nulls,
        SUM(CASE WHEN device IS NULL THEN 1 ELSE 0 END) AS device_nulls,
        SUM(CASE WHEN channel IS NULL THEN 1 ELSE 0 END) AS channel_nulls,
        SUM(CASE WHEN device_fingerprint IS NULL THEN 1 ELSE 0 END) AS device_fingerprint_nulls,
        SUM(CASE WHEN ip_address IS NULL THEN 1 ELSE 0 END) AS ip_address_nulls,
        SUM(CASE WHEN distance_from_home IS NULL THEN 1 ELSE 0 END) AS distance_from_home_nulls,
        SUM(CASE WHEN high_risk_merchant IS NULL THEN 1 ELSE 0 END) AS high_risk_merchant_nulls,
        SUM(CASE WHEN transaction_hour IS NULL THEN 1 ELSE 0 END) AS transaction_hour_nulls,
        SUM(CASE WHEN weekend_transaction IS NULL THEN 1 ELSE 0 END) AS weekend_transaction_nulls,
        SUM(CASE WHEN velocity_last_hour IS NULL THEN 1 ELSE 0 END) AS velocity_last_hour_nulls,
        SUM(CASE WHEN is_fraud IS NULL THEN 1 ELSE 0 END) AS is_fraud_nulls
    FROM transactions_raw
""").show(truncate=False, vertical=True)
# Out:
# -RECORD 0------------------------
#  transaction_id_nulls      | 0
#  customer_id_nulls         | 0
#  card_number_nulls         | 0
#  timestamp_nulls           | 0
#  merchant_category_nulls   | 0
#  merchant_type_nulls       | 0
#  merchant_nulls            | 0
#  amount_nulls              | 0
#  currency_nulls            | 0
#  country_nulls             | 0
#  city_nulls                | 0
#  city_size_nulls           | 0
#  card_type_nulls           | 0
#  card_present_nulls        | 0
#  device_nulls              | 0
#  channel_nulls             | 0
#  device_fingerprint_nulls  | 0
#  ip_address_nulls          | 0
#  distance_from_home_nulls  | 0
#  high_risk_merchant_nulls  | 0
#  transaction_hour_nulls    | 0
#  weekend_transaction_nulls | 0
#  velocity_last_hour_nulls  | 0
#  is_fraud_nulls            | 0

# %%
spark.sql("""
    SELECT COUNT(*) AS duplicated_rows
    FROM (
        SELECT
            transaction_id, customer_id, card_number, timestamp, merchant_category,
            merchant_type, merchant, amount, currency, country, city, city_size,
            card_type, card_present, device, channel, device_fingerprint, ip_address,
            distance_from_home, high_risk_merchant, transaction_hour,
            weekend_transaction, velocity_last_hour, is_fraud,
            COUNT(*) AS qty
        FROM transactions_raw
        GROUP BY
            transaction_id, customer_id, card_number, timestamp, merchant_category,
            merchant_type, merchant, amount, currency, country, city, city_size,
            card_type, card_present, device, channel, device_fingerprint, ip_address,
            distance_from_home, high_risk_merchant, transaction_hour,
            weekend_transaction, velocity_last_hour, is_fraud
        HAVING COUNT(*) > 1
    ) t
""").show()
# Out:
# +---------------+
# |duplicated_rows|
# +---------------+
# |              0|
# +---------------+

# %% [markdown]
# ## Limpeza inicial

# %%
spark.sql("""
    SELECT
        SUM(CASE WHEN TRIM(transaction_id) = '' THEN 1 ELSE 0 END) AS transaction_id_empty,
        SUM(CASE WHEN TRIM(customer_id) = '' THEN 1 ELSE 0 END) AS customer_id_empty,
        SUM(CASE WHEN TRIM(merchant_category) = '' THEN 1 ELSE 0 END) AS merchant_category_empty,
        SUM(CASE WHEN TRIM(merchant_type) = '' THEN 1 ELSE 0 END) AS merchant_type_empty,
        SUM(CASE WHEN TRIM(merchant) = '' THEN 1 ELSE 0 END) AS merchant_empty,
        SUM(CASE WHEN TRIM(currency) = '' THEN 1 ELSE 0 END) AS currency_empty,
        SUM(CASE WHEN TRIM(country) = '' THEN 1 ELSE 0 END) AS country_empty,
        SUM(CASE WHEN TRIM(city) = '' THEN 1 ELSE 0 END) AS city_empty,
        SUM(CASE WHEN TRIM(city_size) = '' THEN 1 ELSE 0 END) AS city_size_empty,
        SUM(CASE WHEN TRIM(card_type) = '' THEN 1 ELSE 0 END) AS card_type_empty,
        SUM(CASE WHEN TRIM(device) = '' THEN 1 ELSE 0 END) AS device_empty,
        SUM(CASE WHEN TRIM(channel) = '' THEN 1 ELSE 0 END) AS channel_empty,
        SUM(CASE WHEN TRIM(device_fingerprint) = '' THEN 1 ELSE 0 END) AS device_fingerprint_empty,
        SUM(CASE WHEN TRIM(ip_address) = '' THEN 1 ELSE 0 END) AS ip_address_empty,
        SUM(CASE WHEN TRIM(velocity_last_hour) = '' THEN 1 ELSE 0 END) AS velocity_last_hour_empty
    FROM transactions_raw
""").show(truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------
#  transaction_id_empty     | 0
#  customer_id_empty        | 0
#  merchant_category_empty  | 0
#  merchant_type_empty      | 0
#  merchant_empty           | 0
#  currency_empty           | 0
#  country_empty            | 0
#  city_empty               | 0
#  city_size_empty          | 0
#  card_type_empty          | 0
#  device_empty             | 0
#  channel_empty            | 0
#  device_fingerprint_empty | 0
#  ip_address_empty         | 0
#  velocity_last_hour_empty | 0

# %% [markdown]
# # Etapa 2 - Pre-processamento e seleção inicial de atributos.ibutos

# %% [markdown]
# ## Selecao inicial de features

# %%
selected_dataframe = dataframe.select(
    "merchant_category",
    "merchant_type",
    "amount",
    "currency",
    "country",
    "city",
    "city_size",
    "card_type",
    "card_present",
    "device",
    "channel",
    "distance_from_home",
    "high_risk_merchant",
    "transaction_hour",
    "weekend_transaction",
    "velocity_last_hour",
    "is_fraud"
).createOrReplaceTempView("transactions_selected")

# %%
spark.sql("SELECT * FROM transactions_selected LIMIT 10").show(truncate=False)
# Out:
# +-----------------+-------------+---------+--------+---------+------------+---------+---------------+------------+-----------+-------+------------------+------------------+----------------+-------------------+------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# |merchant_category|merchant_type|amount   |currency|country  |city        |city_size|card_type      |card_present|device     |channel|distance_from_home|high_risk_merchant|transaction_hour|weekend_transaction|velocity_last_hour                                                                                                                                    |is_fraud|
# +-----------------+-------------+---------+--------+---------+------------+---------+---------------+------------+-----------+-------+------------------+------------------+----------------+-------------------+------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# |Education        |supplies     |513.59   |USD     |USA      |Los Angeles |large    |Gold Credit    |false       |Edge       |web    |0                 |false             |22              |false              |{'num_transactions': 222, 'total_amount': 6001328.808632168, 'unique_merchants': 87, 'unique_countries': 12, 'max_single_amount': 1108920.8766736432} |false   |
# |Entertainment    |events       |683010.87|NGN     |Nigeria  |Unknown City|medium   |Basic Credit   |false       |Android App|mobile |1                 |true              |22              |false              |{'num_transactions': 110, 'total_amount': 6437171.840036886, 'unique_merchants': 70, 'unique_countries': 9, 'max_single_amount': 2574176.473608244}   |true    |
# |Gas              |major        |16.76    |BRL     |Brazil   |Unknown City|medium   |Platinum Credit|true        |Chip Reader|pos    |1                 |false             |22              |false              |{'num_transactions': 268, 'total_amount': 12635383.309312332, 'unique_merchants': 94, 'unique_countries': 12, 'max_single_amount': 3419844.28627481}  |true    |
# |Education        |supplies     |130608.99|RUB     |Russia   |Unknown City|medium   |Basic Credit   |false       |Edge       |web    |1                 |false             |22              |false              |{'num_transactions': 21, 'total_amount': 223751.77196771436, 'unique_merchants': 19, 'unique_countries': 5, 'max_single_amount': 130608.99321462799}  |true    |
# |Grocery          |online       |112.31   |EUR     |France   |Unknown City|medium   |Basic Credit   |false       |Safari     |web    |0                 |false             |22              |false              |{'num_transactions': 180, 'total_amount': 7148465.839493054, 'unique_merchants': 80, 'unique_countries': 12, 'max_single_amount': 835490.9820599003}  |false   |
# |Healthcare       |medical      |167.09   |GBP     |UK       |Unknown City|medium   |Basic Credit   |false       |Safari     |web    |0                 |false             |22              |false              |{'num_transactions': 211, 'total_amount': 5142126.080680595, 'unique_merchants': 87, 'unique_countries': 12, 'max_single_amount': 1420299.292879108}  |false   |
# |Grocery          |online       |33008.98 |RUB     |Russia   |Unknown City|medium   |Platinum Credit|false       |iOS App    |mobile |0                 |false             |22              |false              |{'num_transactions': 278, 'total_amount': 25063341.174983762, 'unique_merchants': 95, 'unique_countries': 12, 'max_single_amount': 1022937.8494629767}|false   |
# |Entertainment    |streaming    |31905.93 |JPY     |Japan    |Unknown City|medium   |Platinum Credit|false       |Firefox    |web    |0                 |true              |22              |false              |{'num_transactions': 186, 'total_amount': 22905557.973753765, 'unique_merchants': 86, 'unique_countries': 12, 'max_single_amount': 856973.4519718022} |false   |
# |Gas              |major        |1589.96  |SGD     |Singapore|Unknown City|medium   |Platinum Credit|false       |Safari     |web    |0                 |false             |22              |false              |{'num_transactions': 131, 'total_amount': 3040862.3041007672, 'unique_merchants': 72, 'unique_countries': 9, 'max_single_amount': 521502.50401140127} |false   |
# |Entertainment    |gaming       |12308.08 |RUB     |Russia   |Unknown City|medium   |Basic Debit    |false       |iOS App    |mobile |0                 |true              |22              |false              |{'num_transactions': 448, 'total_amount': 19658433.209997784, 'unique_merchants': 102, 'unique_countries': 12, 'max_single_amount': 1566109.140456305}|false   |
# +-----------------+-------------+---------+--------+---------+------------+---------+---------------+------------+-----------+-------+------------------+------------------+----------------+-------------------+------------------------------------------------------------------------------------------------------------------------------------------------------+--------+

# %% [markdown]
# ## Inspecao inicial de velocity_last_hour

# %%
spark.sql("SELECT velocity_last_hour FROM transactions_selected LIMIT 10").show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------+
# |velocity_last_hour                                                                                                                                    |
# +------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{'num_transactions': 222, 'total_amount': 6001328.808632168, 'unique_merchants': 87, 'unique_countries': 12, 'max_single_amount': 1108920.8766736432} |
# |{'num_transactions': 110, 'total_amount': 6437171.840036886, 'unique_merchants': 70, 'unique_countries': 9, 'max_single_amount': 2574176.473608244}   |
# |{'num_transactions': 268, 'total_amount': 12635383.309312332, 'unique_merchants': 94, 'unique_countries': 12, 'max_single_amount': 3419844.28627481}  |
# |{'num_transactions': 21, 'total_amount': 223751.77196771436, 'unique_merchants': 19, 'unique_countries': 5, 'max_single_amount': 130608.99321462799}  |
# |{'num_transactions': 180, 'total_amount': 7148465.839493054, 'unique_merchants': 80, 'unique_countries': 12, 'max_single_amount': 835490.9820599003}  |
# |{'num_transactions': 211, 'total_amount': 5142126.080680595, 'unique_merchants': 87, 'unique_countries': 12, 'max_single_amount': 1420299.292879108}  |
# |{'num_transactions': 278, 'total_amount': 25063341.174983762, 'unique_merchants': 95, 'unique_countries': 12, 'max_single_amount': 1022937.8494629767}|
# |{'num_transactions': 186, 'total_amount': 22905557.973753765, 'unique_merchants': 86, 'unique_countries': 12, 'max_single_amount': 856973.4519718022} |
# |{'num_transactions': 131, 'total_amount': 3040862.3041007672, 'unique_merchants': 72, 'unique_countries': 9, 'max_single_amount': 521502.50401140127} |
# |{'num_transactions': 448, 'total_amount': 19658433.209997784, 'unique_merchants': 102, 'unique_countries': 12, 'max_single_amount': 1566109.140456305}|
# +------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
spark.sql("""
    SELECT
        velocity_last_hour,
        CAST(regexp_extract(velocity_last_hour, '''num_transactions'': ([0-9]+)', 1) AS INT) AS num_transactions_last_hour,
        CAST(regexp_extract(velocity_last_hour, '''total_amount'': ([0-9]+\\.?[0-9]*)', 1) AS DOUBLE) AS total_amount_last_hour,
        CAST(regexp_extract(velocity_last_hour, '''unique_merchants'': ([0-9]+)', 1) AS INT) AS unique_merchants_last_hour,
        CAST(regexp_extract(velocity_last_hour, '''unique_countries'': ([0-9]+)', 1) AS INT) AS unique_countries_last_hour,
        CAST(regexp_extract(velocity_last_hour, '''max_single_amount'': ([0-9]+\\.?[0-9]*)', 1) AS DOUBLE) AS max_single_amount_last_hour
    FROM transactions_selected
    LIMIT 10
""").show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+----------------------+--------------------------+--------------------------+---------------------------+
# |velocity_last_hour                                                                                                                                    |num_transactions_last_hour|total_amount_last_hour|unique_merchants_last_hour|unique_countries_last_hour|max_single_amount_last_hour|
# +------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+----------------------+--------------------------+--------------------------+---------------------------+
# |{'num_transactions': 222, 'total_amount': 6001328.808632168, 'unique_merchants': 87, 'unique_countries': 12, 'max_single_amount': 1108920.8766736432} |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |
# |{'num_transactions': 110, 'total_amount': 6437171.840036886, 'unique_merchants': 70, 'unique_countries': 9, 'max_single_amount': 2574176.473608244}   |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |
# |{'num_transactions': 268, 'total_amount': 12635383.309312332, 'unique_merchants': 94, 'unique_countries': 12, 'max_single_amount': 3419844.28627481}  |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |
# |{'num_transactions': 21, 'total_amount': 223751.77196771436, 'unique_merchants': 19, 'unique_countries': 5, 'max_single_amount': 130608.99321462799}  |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |
# |{'num_transactions': 180, 'total_amount': 7148465.839493054, 'unique_merchants': 80, 'unique_countries': 12, 'max_single_amount': 835490.9820599003}  |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |
# |{'num_transactions': 211, 'total_amount': 5142126.080680595, 'unique_merchants': 87, 'unique_countries': 12, 'max_single_amount': 1420299.292879108}  |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |
# |{'num_transactions': 278, 'total_amount': 25063341.174983762, 'unique_merchants': 95, 'unique_countries': 12, 'max_single_amount': 1022937.8494629767}|NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |
# |{'num_transactions': 186, 'total_amount': 22905557.973753765, 'unique_merchants': 86, 'unique_countries': 12, 'max_single_amount': 856973.4519718022} |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |
# |{'num_transactions': 131, 'total_amount': 3040862.3041007672, 'unique_merchants': 72, 'unique_countries': 9, 'max_single_amount': 521502.50401140127} |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |
# |{'num_transactions': 448, 'total_amount': 19658433.209997784, 'unique_merchants': 102, 'unique_countries': 12, 'max_single_amount': 1566109.140456305}|NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |
# +------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+----------------------+--------------------------+--------------------------+---------------------------+

# %% [markdown]
# ## Criacao da view tratada para a modelagem

# %%
treated_dataframe = spark.sql("""
    SELECT
        merchant_category,
        merchant_type,
        amount,
        currency,
        country,
        city,
        city_size,
        card_type,
        card_present,
        device,
        channel,
        distance_from_home,
        high_risk_merchant,
        transaction_hour,
        weekend_transaction,
        CAST(regexp_extract(velocity_last_hour, '''num_transactions'': ([0-9]+)', 1) AS INT) AS num_transactions_last_hour,
        CAST(regexp_extract(velocity_last_hour, '''total_amount'': ([0-9]+\\.?[0-9]*)', 1) AS DOUBLE) AS total_amount_last_hour,
        CAST(regexp_extract(velocity_last_hour, '''unique_merchants'': ([0-9]+)', 1) AS INT) AS unique_merchants_last_hour,
        CAST(regexp_extract(velocity_last_hour, '''unique_countries'': ([0-9]+)', 1) AS INT) AS unique_countries_last_hour,
        CAST(regexp_extract(velocity_last_hour, '''max_single_amount'': ([0-9]+\\.?[0-9]*)', 1) AS DOUBLE) AS max_single_amount_last_hour,
        is_fraud
    FROM transactions_selected
""")

treated_dataframe.createOrReplaceTempView("transactions_treated")

# %%
# spark.sql("DESCRIBE transactions_treated").show(truncate=False)
treated_dataframe.printSchema()
spark.sql("SELECT * FROM transactions_treated LIMIT 10").show(truncate=False)
# Out:
# root
#  |-- merchant_category: string (nullable = true)
#  |-- merchant_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- city_size: string (nullable = true)
#  |-- card_type: string (nullable = true)
#  |-- card_present: boolean (nullable = true)
#  |-- device: string (nullable = true)
#  |-- channel: string (nullable = true)
#  |-- distance_from_home: integer (nullable = true)
#  |-- high_risk_merchant: boolean (nullable = true)
#  |-- transaction_hour: integer (nullable = true)
#  |-- weekend_transaction: boolean (nullable = true)
#  |-- num_transactions_last_hour: integer (nullable = true)
#  |-- total_amount_last_hour: double (nullable = true)
#  |-- unique_merchants_last_hour: integer (nullable = true)
#  |-- unique_countries_last_hour: integer (nullable = true)
#  |-- max_single_amount_last_hour: double (nullable = true)
#  |-- is_fraud: boolean (nullable = true)
#
# +-----------------+-------------+---------+--------+---------+------------+---------+---------------+------------+-----------+-------+------------------+------------------+----------------+-------------------+--------------------------+----------------------+--------------------------+--------------------------+---------------------------+--------+
# |merchant_category|merchant_type|amount   |currency|country  |city        |city_size|card_type      |card_present|device     |channel|distance_from_home|high_risk_merchant|transaction_hour|weekend_transaction|num_transactions_last_hour|total_amount_last_hour|unique_merchants_last_hour|unique_countries_last_hour|max_single_amount_last_hour|is_fraud|
# +-----------------+-------------+---------+--------+---------+------------+---------+---------------+------------+-----------+-------+------------------+------------------+----------------+-------------------+--------------------------+----------------------+--------------------------+--------------------------+---------------------------+--------+
# |Education        |supplies     |513.59   |USD     |USA      |Los Angeles |large    |Gold Credit    |false       |Edge       |web    |0                 |false             |22              |false              |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |false   |
# |Entertainment    |events       |683010.87|NGN     |Nigeria  |Unknown City|medium   |Basic Credit   |false       |Android App|mobile |1                 |true              |22              |false              |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |true    |
# |Gas              |major        |16.76    |BRL     |Brazil   |Unknown City|medium   |Platinum Credit|true        |Chip Reader|pos    |1                 |false             |22              |false              |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |true    |
# |Education        |supplies     |130608.99|RUB     |Russia   |Unknown City|medium   |Basic Credit   |false       |Edge       |web    |1                 |false             |22              |false              |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |true    |
# |Grocery          |online       |112.31   |EUR     |France   |Unknown City|medium   |Basic Credit   |false       |Safari     |web    |0                 |false             |22              |false              |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |false   |
# |Healthcare       |medical      |167.09   |GBP     |UK       |Unknown City|medium   |Basic Credit   |false       |Safari     |web    |0                 |false             |22              |false              |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |false   |
# |Grocery          |online       |33008.98 |RUB     |Russia   |Unknown City|medium   |Platinum Credit|false       |iOS App    |mobile |0                 |false             |22              |false              |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |false   |
# |Entertainment    |streaming    |31905.93 |JPY     |Japan    |Unknown City|medium   |Platinum Credit|false       |Firefox    |web    |0                 |true              |22              |false              |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |false   |
# |Gas              |major        |1589.96  |SGD     |Singapore|Unknown City|medium   |Platinum Credit|false       |Safari     |web    |0                 |false             |22              |false              |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |false   |
# |Entertainment    |gaming       |12308.08 |RUB     |Russia   |Unknown City|medium   |Basic Debit    |false       |iOS App    |mobile |0                 |true              |22              |false              |NULL                      |NULL                  |NULL                      |NULL                      |NULL                       |false   |
# +-----------------+-------------+---------+--------+---------+------------+---------+---------------+------------+-----------+-------+------------------+------------------+----------------+-------------------+--------------------------+----------------------+--------------------------+--------------------------+---------------------------+--------+

# %% [markdown]
# ## Validacao do tratamento de velocity_last_hour

# %%
spark.sql("""
    SELECT
        SUM(CASE WHEN num_transactions_last_hour IS NULL THEN 1 ELSE 0 END) AS num_transactions_last_hour_nulls,
        SUM(CASE WHEN total_amount_last_hour IS NULL THEN 1 ELSE 0 END) AS total_amount_last_hour_nulls,
        SUM(CASE WHEN unique_merchants_last_hour IS NULL THEN 1 ELSE 0 END) AS unique_merchants_last_hour_nulls,
        SUM(CASE WHEN unique_countries_last_hour IS NULL THEN 1 ELSE 0 END) AS unique_countries_last_hour_nulls,
        SUM(CASE WHEN max_single_amount_last_hour IS NULL THEN 1 ELSE 0 END) AS max_single_amount_last_hour_nulls
    FROM transactions_treated
""").show(truncate=False, vertical=True)
# Out:
# -RECORD 0------------------------------------
#  num_transactions_last_hour_nulls  | 7483766
#  total_amount_last_hour_nulls      | 7483766
#  unique_merchants_last_hour_nulls  | 7483766
#  unique_countries_last_hour_nulls  | 7483766
#  max_single_amount_last_hour_nulls | 7483766
